# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = "stock_yfinance_data.csv"
df = pd.read_csv(file_path)

print(df.info())
print(df.head())

df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values(by="Date")
plt.figure(figsize=(10,30))
for stock in df["Stock Name"].unique():
    stock_df = df[df["Stock Name"] == stock]
    plt.plot(stock_df["Date"], stock_df["Close"], label=stock)

plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("Stock Closing Prices Over Time")
plt.legend()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6300 entries, 0 to 6299
# Data columns (total 8 columns):
# Date          6300 non-null object
# Open          6300 non-null float64
# High          6300 non-null float64
# Low           6300 non-null float64
# Close         6300 non-null float64
# Adj Close     6300 non-null float64
# Volume        6300 non-null int64
# Stock Name    6300 non-null object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 393.8+ KB
# None
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 1  2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2  2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 3  2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 4  2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
#
#      Volume Stock Name
# 0  53868000       TSLA
# 1  51094200       TSLA
# 2  91449900       TSLA
# 3  55297800       TSLA
# 4  43898400       TSLA
